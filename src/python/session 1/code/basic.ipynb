# %%
print("wellcome")
# Out:
# wellcome

# %%
x=10
y=20
print("value", x ,"value of : y",y)
# Out:
# value 10 value of : y 20

# %%
print(f"the value of x {10} and the value of y is {20} ")
# Out:
# the value of x 10 and the value of y is 20

# %%
name=emad_nader_atta
curse= ai_and_data_science
id= 333
print(f"my name is {"emad_nader_atta"} and my curse is {"ai_and_data_science"} and my id value {333}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 name=emad_nader_atta
#       2 curse= ai_and_data_science
#       3 id= 333
#
# NameError: name 'emad_nader_atta' is not defined

# %%
sent_1 ="welcom into our company"
split_result = sent_1.split()
split_2 =''.join(split_result)
print(sent_2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 4
#       2 split_result = sent_1.split()
#       3 split_2 =''.join(split_result)
# ----> 4 print(sent_2)
#
# NameError: name 'sent_2' is not defined

# %%
list can be represented by[]
list_one =[1,2,3,4,"amit","learning",True,["ml","ds"]]]
print(type(list_one))
# Out:
#   Cell In[10], line 2
#     list_one =[1,2,3,4,"amit","learning",True,["ml","ds"]]]
#                                                           ^
# SyntaxError: unmatched ']'

# %%
tuple_1 = (3,2,41)
print(type(tuple_1))
conv_list = list(tuple_1)
conv_list[2] = 50
new_tuple = tuple(conv_list)
print (new_tuple)
# Out:
# <class 'tuple'>
# (3, 2, 50)

# %%
dict_1 ={"key1":12.5,"key2":depi",4:}
